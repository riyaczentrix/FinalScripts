# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import hdbscan
from collections import defaultdict

# Step 1: Load the Excel file and problem_reported column
df = pd.read_excel("full_cleand_data_for_rag.xlsx")  # Reading Excel file

column = 'problem_reported'

# Step 2: Extract cleaned problem_reported text
if column not in df.columns:
    raise ValueError("Column 'problem_reported' not found in the Excel file.")
texts = df[column].fillna('').tolist()  # Replace NaN with empty string

# Step 3: Convert problem_reported texts to sentence embeddings
model = SentenceTransformer('sentence-t5-large')
embeddings = model.encode(texts, show_progress_bar=True)

# Step 4: Run HDBSCAN clustering
clusterer = hdbscan.HDBSCAN(min_cluster_size=2, metric='euclidean')
labels = clusterer.fit_predict(embeddings)

# Step 5: Save cluster labels back to the DataFrame
df['Cluster'] = labels

# Step 6: Save the updated DataFrame to a new CSV file
df.to_csv("clustered_emails.csv", index=False)  # Saving as CSV
print("Clustered tickets saved to 'clustered_emails.csv'.")

# (Optional) Step 7: Print clusters to console
clusters = defaultdict(list)
for i, label in enumerate(labels):
    clusters[label].append(texts[i])

for label, grouped_texts in clusters.items():
    print(f"\n🧠 Intent Cluster {label} ({len(grouped_texts)} tickets):")
    for text in grouped_texts[:5]:  # Print only first 5 per cluster to avoid overload
        print(f" - {text}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 2_Dense/model.safetensors:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# 2_Dense/pytorch_model.bin:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# Batches:   0%|          | 0/1563 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Clustered tickets saved to 'clustered_emails.csv'.
#
# 🧠 Intent Cluster -1 (22242 tickets):
#  - Czentrix is not working properly in UPE CIrcle.
#  - Server Access through dedicated IP only
#  - Please provide Voice Data
#  - CLI Change Query
#  - Robo Calls Data Required
#
# 🧠 Intent Cluster 1 (14 tickets):
#  - ADVISORY: BUSINESS CONTINUITY PLANNING - Single Uplink / HA Uplink
#  - ADVISORY: BUSINESS CONTINUITY PLANNING - Single Uplink / HA Uplink
#  - ADVISORY: BUSINESS CONTINUITY PLANNING - Single Uplink / HA Uplink
#  - ADVISORY: BUSINESS CONTINUITY PLANNING - Single Uplink / HA Uplink
#  - ADVISORY: BUSINESS CONTINUITY PLANNING - Single Uplink / HA Uplink
#
# 🧠 Intent Cluster 114 (3 tickets):
#  - Reminder-2: Cust ID: 35980 | Urgent Notice: End of Life/End of Support Inventory | July-2025
#  - Reminder-1: Cust ID: 35980 | Urgent Notice: End of Life/End of Support Inventory | June-2025
#  - Cust ID: 35980 | Urgent Notice: End of Life/End of Support Inventory | June-2025
#
# 🧠 Intent Cluster 1137 (57 tickets):
#  - test
#  - test
#  - test
#  - test
#  - test
#
# 🧠 Intent Cluster 4278 (4 tickets):
#  - Czentrix is not working.
#  - Czentrix is not working.
#  - Czentrix is not working.
#  - Czentrix is not working.
#
# 🧠 Intent Cluster 4196 (7 tickets):
#  - C-Zen issue
#  - C-Zen issue
#  - C-Zen issue
#  - C-Zen issue
#  - C-Zen issue
#
# 🧠 Intent Cluster 1576 (5 tickets):
#  - License transfer
#  - License transfer
#  - License transfer
#  - License transfer
#  - License transfer
#
# 🧠 Intent Cluster 3502 (5 tickets):
#  - Call forwarding not working
#  - Unable to do call forwarding
#  - call forwarding not working
#  - Call forwarding option not work
#  - Unable to forward the call
#
# 🧠 Intent Cluster 1900 (7 tickets):
#  - Id deactivation request
#  - Account Deactivation Request
#  - De-activation request
#  - ID Deactivation
#  - De-activation request
#
# 🧠 Intent Cluster 545 (18 tickets):
#  - MyNTTI Regenerate Password
#  - MyNTTI Regenerate Password
#  - MyNTTI Regenerate Password
#  - MyNTTI Regenerate Password
#  - MyNTTI Regenerate Password
#
# 🧠 Intent Cluster 1145 (10 tickets):
#  - Enable Incoming Calls - Nps_Scaler
#  - Enable Incoming Calls - Nps_Scaler
#  - Enable Incoming Calls - Nps_Scaler
#  - Enable Incoming Calls - Nps_Scaler
#  - Enable Incoming Calls - Nps_Scaler
#
# 🧠 Intent Cluster 1774 (10 tickets):
#  - RE: Auto Predictive Dialing
#  - Auto Predictive Dialing
#  - Auto Predictive Dialing
#  - Predictive Dialing Capability
#  - issue with predictive calls
#
# 🧠 Intent Cluster 3843 (11 tickets):
#  - Inbound call not landing
#  - Inbound call not landing
#  - Inbound Call not Landing
#  - Inbound Call not Landing
#  - Inbound call not landing
#
# 🧠 Intent Cluster 4024 (37 tickets):
#  - Dialer not dial the number
#  - Dialer not dial the number
#  - Dialer not dial the number
#  - Dialer not dial the number
#  - Dialer not dial the number
#
# 🧠 Intent Cluster 2747 (25 tickets):
#  - Change contact number
#  - Change contact number
#  - Change contact number
#  - Change contact number
#  - Change contact number
#
# 🧠 Intent Cluster 4239 (7 tickets):
#  - Inbound Call Issue in C-Zentrix
#  - Inbound Call Issue in C-Zentrix
#  - C-zentrix Call receiving issue
#  - C-zentrix outbound call issue
#  - C-Zentrix Inbound and Outbound calls issue
#
# 🧠 Intent Cluster 2164 (7 tickets):
#  - INT Cloud || DID unmapping request
#  - INT Cloud || DID Un-map request
#  - INT Cloud || DID mapping and unmapping request
#  - INT Cloud || DID unmapping request
#  - INT Cloud || DID unmapping request
#
# 🧠 Intent Cluster 4128 (3 tickets):
#  - Facing Outbound Call disconnect Issue in C Zentrix Server
#  - Facing Call disconnect Issue in C Zentrix
#  - Facing Call disconnect Issue in C Zentrix
#
# 🧠 Intent Cluster 265 (6 tickets):
#  - Query
#  - Query
#  - inquery
#  - Query
#  - Re: Regarding query
#
# 🧠 Intent Cluster 1156 (12 tickets):
#  - Leads details
#  - Leads details
#  - Leads details
#  - Leads details
#  - Leads details
#
# 🧠 Intent Cluster 4147 (15 tickets):
#  - Unable to make outbound calls
#  - Unable to make outbound calls
#  - Unable to make outbound calls
#  - Unable to make outbound calls
#  - Unable to make outbound calls
#
# 🧠 Intent Cluster 2275 (3 tickets):
#  - Error in data uploading
#  - Error Encountered During Data Upload
#  - Error on uploading data
#
# 🧠 Intent Cluster 3024 (6 tickets):
#  - Issue with Report Download
#  - Issue with Report Downloads
#  - Report download issue
#  - Report download Issue
#  - Report download issue
#
# 🧠 Intent Cluster 1469 (17 tickets):
#  - Re: Rename cloud agents
#  - Name update to agent ID- Cloud
#  - Name Update - Cloud
#  - Update ID Name - Cloud
#  - Agent ID names to be updated - Cloud
#
# 🧠 Intent Cluster 2044 (2 tickets):
#  - Re: C-Zentrix Access | Syeda Arshiya
#  - C-Zentrix Access _ Altaf Sayyed
#
# 🧠 Intent Cluster 1716 (8 tickets):
#  - Creation of C-Zen ID || I-DOT Operations
#  - Creation of C-zen Id || IDOT - Campaign
#  - Creation of C-zen Id || IDOT - Campaign
#  - Creation of C-zen Id || IDOT - Campaign
#  - Creation of C-zen Id || IDOT - Campaign
#
# 🧠 Intent Cluster 133 (19 tickets):
#  - Re: Revised Scheduled Planned Event - Intimation || PE040720251033 ||
#  - Re: Planned Event - Intimation || PE010720251103 ||
#  - Re: Planned Event - Intimation || PE010720251100||
#  - Re: Planned Event - Intimation || PE240620251020 ||
#  - Re: Planned Event - Intimation || PE180620251065 ||
#
# 🧠 Intent Cluster 2589 (3 tickets):
#  - Re: ll Bug in C-Sat Report ll
#  - RE: Bug in C-Sat Report
#  - Bug in C-Sat Report
#
# 🧠 Intent Cluster 3364 (5 tickets):
#  - C-zentrix lagging Issue
#  - C-Zentrix Working Slow
#  - C-Zentrix Working Slow
#  - C-zentrix working slow
#  - C-zentrix working slow
#
# 🧠 Intent Cluster 282 (6 tickets):
#  - {Internal} Removal of 05 GSM SIMs of Rialtes
#  - Removal of 03 GSM SIMs of Laiqa
#  - Removal of 06 GSM SIMs of Reliance General Insurance
#  - Removal of 17 GSM SIMs of Sundaram BPO
#  - Reg: Temporary 5 no\\ s sim remove from GSM port
#
# 🧠 Intent Cluster 2155 (4 tickets):
#  - DID Mapping Request for OYO_Spanish Campaign
#  - INT Cloud || Request for DID Mapping to OYO IDs for OYO_Spanish Campaign
#  - INT Cloud || Request for DID Mapping for OYO_Spanish Campaign
#  - INT Cloud || Request for DID Mapping for Campaign - OYO_Spanish
#
# 🧠 Intent Cluster 2692 (27 tickets):
#  - Agent 499321 is facing voice issue.
#  - Facing voice issue in agent id - 396634
#  - Voice issue in Angent 496100
#  - Agents are facing  voice breaking issue
#  - Agent facing a voice issue
#
# 🧠 Intent Cluster 1526 (3 tickets):
#  - C Zentrix Issue / UAE OMT Campaign
#  - C Zentrix Issue / UAE OMT Campaign
#  - C zentrix issue / UAE RO campaign
#
# 🧠 Intent Cluster 1691 (4 tickets):
#  - Need to shutdown the server
#  - need to shutdown the server
#  - Need to shut down server
#  - Need to shut down server
#
# 🧠 Intent Cluster 655 (4 tickets):
#  - Response not received for July month
#  - Response Not Received For 2nd June
#  - Response Not received for 2,3 and 4th may
#  - Response Not Receive for Date 25 & 26 July
#
# 🧠 Intent Cluster 2473 (4 tickets):
#  - Recording required_177225372
#  - Recording required_175417674
#  - Recording required_177648409
#  - 625556055_Recording required
#
# 🧠 Intent Cluster 3256 (7 tickets):
#  - INT Cloud || PPM calling issue
#  - INT Cloud || PPM calling issue
#  - INT Cloud || Calling issue
#  - INT cloud || PPM calling issue
#  - INT Cloud || PPM calling issue
#
# 🧠 Intent Cluster 148 (4 tickets):
#  - SAT Alarm Discrepancy
#  - SAT alarm calls not going perfectly to all roles
#  - SAT alarm calls not going perfectly to all roles
#  - SAT alarm calls not going perfectly to all roles
#
# 🧠 Intent Cluster 168 (3 tickets):
#  - Action Against Abandon ENable
#  - Action Against Abandon Calls For BCabs
#  - Regarding Action Against Abandon - C-Zentrix
#
# 🧠 Intent Cluster 1553 (3 tickets):
#  - license details
#  - License details
#  - Licenses Details
#
# 🧠 Intent Cluster 4152 (2 tickets):
#  - C- Zentrix Issue || Call Not Landing !!
#  - C-Zen Issue || Call not Landing
#
# 🧠 Intent Cluster 3168 (4 tickets):
#  - Reset C-zentrix password: Shabnam Mirza
#  - Reset Czentrix Password- Shabnam Mirza
#  - Reset Czentrix Password- Shabnam Mirza
#  - Re: Czentrix Password- Shabnam Mirza
#
# 🧠 Intent Cluster 2868 (9 tickets):
#  - Not able to login the user
#  - User can not login
#  - User can not login
#  - User unable to login
#  - User not able to login
#
# 🧠 Intent Cluster 435 (3 tickets):
#  - Robo and Preview Backup
#  - Robo and Preview Backup (30-Oct-24)
#  - Robo and Preview Backup--12\\ Oct-24
#
# 🧠 Intent Cluster 809 (26 tickets):
#  - Cloud POC deactivation | TE | Anand Rathi Investment Services
#  - Cloud POC deactivation | Anand Rathi Investment Services
#  - Cloud POC deactivation | CRY NGO
#  - Cloud POC deactivation | Pinnacle Teleservices Pvt Ltd
#  - Cloud POC deactivation | Anand Rathi
#
# 🧠 Intent Cluster 1934 (5 tickets):
#  - CRM field adding request
#  - CRM field adding request
#  - Addition in CRM Field
#  - Create CRM Fields
#  - Fields Add In CRM ||
#
# 🧠 Intent Cluster 3073 (4 tickets):
#  - Dialer ID Creation for New Employee - DFC
#  - Dialer ID Creation for New Employee - DFC
#  - Dialer ID Creation for New Employee - DFC
#  - Dialer ID Creation for new employee\\ s- DFC
#
# 🧠 Intent Cluster 1328 (13 tickets):
#  - Dialer password reset
#  - Dialer password reset
#  - Dialer password reset
#  - Dialer password reset
#  - Dialer password reset
#
# 🧠 Intent Cluster 3713 (11 tickets):
#  - Unable to disconnect the call through Czen.
#  - Unable to disconnect the call through Czen.
#  - Unable to disconnect the call through Czen.
#  - Unable to disconnect the call through Czen.
#  - Unable to Disconnect the call through The C-zen
#
# 🧠 Intent Cluster 406 (14 tickets):
#  - Welcome TOWARDS VISION TECHNOLOGIES LIMITED
#  - Welcome TOWARDS VISION TECHNOLOGIES LIMITED
#  - Welcome TOWARDS VISION TECHNOLOGIES LIMITED
#  - Welcome TOWARDS VISION TECHNOLOGIES LIMITED
#  - Welcome TOWARDS VISION TECHNOLOGIES LIMITED
#
# 🧠 Intent Cluster 2457 (23 tickets):
#  - IVR Non-Working Hours
#  - IVR Non-Working Hours
#  - IVR Non-Working Hours
#  - IVR Non-Working Hours
#  - IVR Non-Working Hours
#
# 🧠 Intent Cluster 2814 (7 tickets):
#  - C-Zentrix Issue (Worklog Page Not Opening)
#  - C-zentrix loging Issue || C-Zentrix page not open
#  - C-Zentrix Work-Log Page is not open.
#  - C-Zentrix Worklog window not Opened
#  - C-Zentrix Work-Log Page is not open.
#
# 🧠 Intent Cluster 4133 (4 tickets):
#  - calls are not connecting
#  - calls are not connecting
#  - calls are not connecting.
#  - calls are not connecting
#
# 🧠 Intent Cluster 3908 (14 tickets):
#  - Call not landing
#  - Call not landing
#  - Call not landing
#  - Call not landing
#  - Call not landing
#
# 🧠 Intent Cluster 4393 (5 tickets):
#  - Unable to login in C zentrix
#  - Unable to login in C - zentrix
#  - Unable to login in C - zentrix
#  - Unable to login in C- zentrix
#  - Unable to login in C Zentrix
#
# 🧠 Intent Cluster 2684 (8 tickets):
#  - C-zentrix licence
#  - C-zentrix License
#  - C-zentrix License
#  - C-zentrix License
#  - C zentrix License
#
# 🧠 Intent Cluster 4332 (7 tickets):
#  - Unable To login C-zen
#  - Regarding unable to login C-zen
#  - Regarding unable to login C-zen
#  - Unable to login C Zen
#  - Unable to login c-zen
#
# 🧠 Intent Cluster 4283 (15 tickets):
#  - Czentrix is not working
#  - Czentrix is not working
#  - Czentrix is not working
#  - Czentrix is not working
#  - Czentrix is not working
#
# 🧠 Intent Cluster 4413 (3 tickets):
#  - c-zentrix login issue
#  - c-zentrix login issue
#  - c-zentrix login issue,
#
# 🧠 Intent Cluster 3759 (9 tickets):
#  - Unable to login
#  - Unable to login
#  - Unable to login
#  - Unable to login
#  - Unable to login
#
# 🧠 Intent Cluster 3775 (4 tickets):
#  - Log in Issue in C-Zentrix //North Region
#  - C-zentrix Login Issue // North Region
#  - C-zentrix Login Issue // North Region
#  - Unable to login C-zentrix // North Region
#
# 🧠 Intent Cluster 4319 (15 tickets):
#  - Unable to make call through C_Zentrix
#  - Unable to make call through C_Zentrix
#  - Unable to make calls through C-Zentrix Call
#  - Unable to make calls through C-Zentrix Call
#  - Unable to make calls through C-zentrix
#
# 🧠 Intent Cluster 2764 (2 tickets):
#  - Request to change DID
#  - Request change for DID
#
# 🧠 Intent Cluster 2146 (13 tickets):
#  - Auto Call
#  - Auto call generated from dialer
#  - Auto Dialer
#  - Auto Dialer
#  - Auto Dialing Function
#
# 🧠 Intent Cluster 1720 (3 tickets):
#  - DID change
#  - DID change
#  - DID change
#
# 🧠 Intent Cluster 1899 (11 tickets):
#  - Request For ID Deletion ||
#  - ID Deletion Request
#  - RE: Request For ID Deletion-Czen
#  - DEACTIVATE CZEN ID
#  - Delete Czen ID
#
# 🧠 Intent Cluster 2174 (4 tickets):
#  - New Cloud JRF | OID-04072025-0316 | Robo Call License || Bachatt
#  - New Cloud JRF | OID-04072025-0326| 8 Robo Call License || Bachatt
#  - New Cloud JRF | OID-30062025-0297 | 3 Robo Call License || Bachatt (Trusave )
#  - New Cloud JRF : OID-16062025-0265 - Robo Call License (Bachatt) || Trusave Fintech P Ltd
#
# 🧠 Intent Cluster 2670 (4 tickets):
#  - South Region C-Zentrix issue
#  - South Region C-Zentrix issue
#  - South Region C-Zentrix issue
#  - Czentrix Issue ||South Region
#
# 🧠 Intent Cluster 4277 (18 tickets):
#  - Czentrix Calling Issue
#  - Czentrix Calling Issue
#  - Czentrix Calling Issue
#  - Czentrix Calling Issue
#  - Czentrix Calling Issue
#
# 🧠 Intent Cluster 2324 (7 tickets):
#  - New Cloud JRF : OID-04072025-0325 | 1 Additional License || Kyno Health
#  - New Cloud JRF : OID-07062025-0248 - 2 Additional Licenses (Kyno Health) || Huami Technologies Pvt Ltd
#  - New Cloud JRF : OID-21052025-0219 - 1 Additional License (Kyno Health) || Huami Technologies Pvt Ltd
#  - New Cloud JRF : OID-20052025-0218- 1 Additional License (Kyno Health) || Haumi Technologies Pvt Ltd
#  - New Cloud JRF : OID-14052025-0213 - 2 Additional Licenses (Kyno Health) || Huami Technologies Pvt Ltd
#
# 🧠 Intent Cluster 3087 (3 tickets):
#  - New agent ID required
#  - New Agent Id Required
#  - New Agent ID Required
#
# 🧠 Intent Cluster 207 (7 tickets):
#  - New client Shivshanker
#  - New client Yogendera
#  - New client name is oolL
#  - New client Udhay
#  - New client Bhavesh
#
# 🧠 Intent Cluster 3184 (3 tickets):
#  - calling issue via CRM
#  - CRM Call issue
#  - CRM Outcall Issue
#
# 🧠 Intent Cluster 4272 (18 tickets):
#  - Unable to make call through CZENTRIX.
#  - Unable to make call through CZENTRIX.
#  - Unable to make call through CZENTRIX.
#  - Unable to make call through CZENTRIX.
#  - Unable to make call through CZENTRIX.
#
# 🧠 Intent Cluster 4138 (29 tickets):
#  - Calls are not connecting
#  - Calls are not connecting
#  - Calls are not connecting
#  - Calls are not connecting
#  - Calls are not connecting
#
# 🧠 Intent Cluster 3371 (6 tickets):
#  - Calls are not visible in Queue
#  - Call queue is not showing.
#  - Calls are not visible in queue
#  - Calls Not Reflecting in Queue
#  - Re: Calls not showing in queue
#
# 🧠 Intent Cluster 4020 (10 tickets):
#  - Re: Call dialing issue
#  - Call dialing issue
#  - Call Dialling issue
#  - Problem in Dialing
#  - Dialing Issue
#
# 🧠 Intent Cluster 1992 (5 tickets):
#  - Inbound & Outbound Calling Stop Today
#  - Inbound & Outbound Calling Stop Today
#  - INBOUND & OUTBOUND CALLING Stop
#  - INBOUND & OUTBOUND CALLING STOP TODAY & TOMORROW
#  - Inbound & Outbound calling Timing Stop Today & Tomorrow,
#
# 🧠 Intent Cluster 4304 (4 tickets):
#  - C-zentrix system Issue
#  - C-zentrix system Issue
#  - C-zentrix system Issue
#  - c-zentrix system Issue
#
# 🧠 Intent Cluster 4032 (9 tickets):
#  - Dialer Not Working
#  - Dialer Not Working
#  - Dialer Not Working
#  - Dialer Not Working
#  - Dialer Not Working
#
# 🧠 Intent Cluster 1543 (7 tickets):
#  - License renewal for the month of July
#  - License renewal for the month of June
#  - License renewal for the month of June
#  - RE: License renewal for June Month
#  - License renewal for June Month
#
# 🧠 Intent Cluster 2141 (6 tickets):
#  - outbond call is not working in uat
#  - In bond call not coming
#  - In bond call not coming
#  - Outbond call not working properly
#  - out bond call is  not working
#
# 🧠 Intent Cluster 1819 (4 tickets):
#  - Indus Call Discrepancy || Jun-25
#  - Indus Call Discrepancy || May-25
#  - Re: Indus Call Discrepancy || Apr-25
#  - Indus Call Discrepancy || Jan-25
#
# 🧠 Intent Cluster 733 (8 tickets):
#  - SFTP Data base
#  - SFTP Data base
#  - SFTP Data base
#  - SFTP Data base
#  - SFTP Data Base
#
# 🧠 Intent Cluster 4056 (5 tickets):
#  - Calling issue
#  - Calling issue
#  - Calling issue
#  - Calling issue
#  - Calling issue
#
# 🧠 Intent Cluster 3857 (3 tickets):
#  - unable to make international calls -
#  - Unable to make to international calls
#  - unable to make international calls
#
# 🧠 Intent Cluster 3788 (6 tickets):
#  - Re: C-Zentrix ID Creation Required
#  - C-Zentrix ID Creation Required
#  - C-Zentrix ID Creation Required
#  - C-Zentrix ID Creation Required
#  - C-Zentrix ID Creation Required
#
# 🧠 Intent Cluster 1744 (3 tickets):
#  - Mail not receiving
#  - Email not work
#  - Mails  Not Working
#
# 🧠 Intent Cluster 2367 (14 tickets):
#  - New Cloud JRF : OID-03072025-0309 | Incred 1- Supervisor License - Collection Process -
#  - New Cloud JRF : OID-04042025-0014 - 21 Additional License (Collection Process) || Incred Financial Services Limited
#  - New Cloud JRF : OID-13092024-2722 - 3 Additional License - TIDE Platform Pvt Ltd
#  - New Cloud JRF : OID-02072024-2577 Incred 1 Additional License for collection process
#  - New Cloud JRF : OID-10062024-2545 || Incred 1 Additional Blended and supervisor License - Collection Process
#
# 🧠 Intent Cluster 3935 (6 tickets):
#  - C zentrix Call not connecting Issue || 03-JULY-2025
#  - C zentrix Call not connecting Issue || 05-Feb-2025
#  - C zentrix Call not connecting Issue || 05-Feb-2025
#  - C Zentrix Call not connecting Issue || 17-Jan-2025
#  - C zentrix Call not connecting I || 06-Jan-2025
#
# 🧠 Intent Cluster 4310 (3 tickets):
#  - C-Zentrix Login Issue & Call Connection Problem
#  - C-Zentrix Login issue and call not connecting
#  - C-Zentrix Call Not Connecting & Login issue
#
# 🧠 Intent Cluster 1430 (4 tickets):
#  - Inbound & Outbound Calling Timing till Tomorrow Morning 6:00 AM
#  - INBOUND & OUTBOUND CALLING TIMING Tomorrow Morning 6:00 AM
#  - INBOUND & OUTBOUND CALLING TIMING Tomorrow Morning 6:00 AM
#  - INBOUND & OUTBOUND CALLING TIMING Till Tomorrow Morning 6:00 AM
#
# 🧠 Intent Cluster 3661 (4 tickets):
#  - Unable to Login Agent ID
#  - Agent ID not able to login
#  - Not able to login agent id
#  - Unable to login one agent ID
#
# 🧠 Intent Cluster 3789 (5 tickets):
#  - Calls getting Abandoned
#  - Calls Getting Abandoned_
#  - Calls Getting Abandoned_
#  - Calls are getting abandoned
#  - Calls getting abandon
#
# 🧠 Intent Cluster 1011 (4 tickets):
#  - CZen User ID & Campaign
#  - CZen User ID & Campaign for Energy team
#  - CZen User ID & Campaign for Energy team
#  - RE: CZen User ID & Campaign for Energy team.
#
# 🧠 Intent Cluster 3477 (8 tickets):
#  - Fwd: Voice issue
#  - Fwd: Voice Issue
#  - FW: Voice issue
#  - FW: Voice Issue
#  - FW: Voice Issue
#
# 🧠 Intent Cluster 3621 (4 tickets):
#  - Agent Login Issue - X-Lite
#  - agent x-lite login issue
#  - X-lite Agent Login Problem
#  - X-lite Agent Login Problem
#
# 🧠 Intent Cluster 2690 (7 tickets):
#  - Enable incoming calls
#  - Enable incoming calls
#  - Enable incoming calls
#  - Enable incoming calls
#  - Enable incoming calls
#
# 🧠 Intent Cluster 267 (4 tickets):
#  - Re: Delivery of your order with CAF 75615000639435 for TOWARDS VISION TECHNOLOGIES LIMITED for SIP Trunk.|| CKT ID-1409307685
#  - Re: FW: Delivery of your order with CAF 75615000638848 for TOWARDS VISION TECHNOLOGIES PRIVATE LIMITED for SIP Trunk || CKT ID-1206838200
#  - Re: Delivery of your order with CAF 9230021219 for VLCC HEALTH CARE LIMITED for SIP Trunk || CKT ID-9228829987
#  - Re: FW: Delivery of your order with CAF 9230020202 for TOWARDS VISION TECHNOLOGIES PRIVATE LIMITED for SIP Trunk.
#
# 🧠 Intent Cluster 313 (6 tickets):
#  - Re: Bangalore Data Center Scheduled Server Maintenance â 19th June 2024
#  - Re: Bangalore Data Center Scheduled Server Maintenance â 19th June 2025
#  - Re: Bangalore Data Center Scheduled Server Maintenance â 19th June 2025
#  - Re: Bangalore Data Center Scheduled Server Maintenance â 19th June 2025
#  - Downtime apply - 4th July 2024
#
# 🧠 Intent Cluster 2829 (2 tickets):
#  - campaign are not showing
#  - Campaigns are not reflecting
#
# 🧠 Intent Cluster 2110 (2 tickets):
#  - New Cloud JRF | OID-01072025-0300 | Quampetence (Ticketing CRM)
#  - New Cloud JRF | OID-01072025-0300 | Quampetence (Ticketing CRM)
#
# 🧠 Intent Cluster 1994 (6 tickets):
#  - outbound call DID number need to change
#  - Change Caller ID
#  - Caller ID Change
#  - Re: Caller id change
#  - Need to Change Caller IDs.
#
# 🧠 Intent Cluster 324 (7 tickets):
#  - Re: Rocket callback issue July 2025-07-01
#  - Re: Rocket Callback Issue
#  - Re: Rocket callback issue
#  - Re: Rocket callback issue
#  - Re: Rocket callback issue
#
# 🧠 Intent Cluster 2037 (3 tickets):
#  - Dialer dialing data multiple time
#  - Dialer is connecting same number more than 3 time
#  - Dialer is connecting same number more than 3 time
#
# 🧠 Intent Cluster 1935 (5 tickets):
#  - Modification in Basic CRM
#  - Addition in Basic CRM
#  - RE: CRM Modification
#  - CRM Modification
#  - CRM Modification
#
# 🧠 Intent Cluster 523 (16 tickets):
#  - Add \\\"Suggested Doctor\\\" Dropdown in Dialer shaydri all campaign
#  - Dr Name Addition in Dialer Formin shaydri all campaign
#  - ADD DR name and Specilitya in shaydri all campaign
#  - Add doctor name_Dr. Mahesh Mangulkar in shaydri all campaign
#  - Add dr name in shaydri process all campaign
#
# 🧠 Intent Cluster 3524 (5 tickets):
#  - IVR update
#  - IVR update
#  - IVR update
#  - IVR update
#  - IVR update
#
# 🧠 Intent Cluster 3526 (7 tickets):
#  - Technical Issue with \\\"Voice Logger\\\" Function in C-Zentrix
#  - Re: [External] RE: C-Zentrix Issue - Voice Logger Issue
#  - Re: C-Zentrix Issue (Voice Logger)
#  - C-Zentrix Voice Logger Issue
#  - Voice logger issue on Czentrix - CI-320510
#
# 🧠 Intent Cluster 2519 (3 tickets):
#  - sip mapping issue
#  - SIP DID Maping issue
#  - sip mapping issue
#
# 🧠 Intent Cluster 330 (8 tickets):
#  - Re: Cross Connect required at Noida DC1 || SOF#139288280_1 (140 series)
#  - Re: Cross Connect required at Noida DC1 || SOF#139288280_1 (MOH2)
#  - Re: Cross Connect required at Noida DC1 || SOF#139288280_1 (MOH)
#  - Re: Cross Connect required at Noida DC1 || SOF#139288280_1
#  - Re: New Cross Connect required at Noida DC1 || SOF#139288280_1
#
# 🧠 Intent Cluster 736 (2 tickets):
#  - Live Call Barging credentials Request
#  - Approvel request for live call access
#
# 🧠 Intent Cluster 1161 (10 tickets):
#  - Lead Details
#  - Lead Details
#  - Lead Details
#  - Lead Details
#  - Lead Details
#
# 🧠 Intent Cluster 1409 (3 tickets):
#  - Call down in Bihar 104
#  - Call down in Bihar 104
#  - Call down in Bihar 104
#
# 🧠 Intent Cluster 4047 (5 tickets):
#  - call issue
#  - Call Issue
#  - Call issue
#  - Call Issue
#  - Call issue
#
# 🧠 Intent Cluster 137 (3 tickets):
#  - VMware tools & Hardware Upgrade report for DC5-Mumbai
#  - VMware tools & Hardware Upgrade report for DC5-Mumbai
#  - VMware tools & Hardware Upgrade report for DC5-Mumbai
#
# 🧠 Intent Cluster 138 (3 tickets):
#  - VMware tools & Hardware Upgrade report for DC2-Bengaluru
#  - VMware tools & Hardware Upgrade report for DC2-Bengaluru
#  - VMware tools & Hardware Upgrade report for DC2-Bengaluru
#
# 🧠 Intent Cluster 2476 (3 tickets):
#  - Call Not Connecting on Toll free Number 18001035004
#  - Call Not Connecting on Toll free Number 18001035004
#  - call are not getting connected on toll free no 18001032244.
#
# 🧠 Intent Cluster 3757 (37 tickets):
#  - Unable to Login
#  - Unable to Login
#  - Unable to Login
#  - Unable to Login
#  - Unable to Login
#
# 🧠 Intent Cluster 798 (3 tickets):
#  - Deactivate : Support Services for Max Life (Setu & Underwriting Process)
#  - Cloud Deactivate Support sErvices || Max Life (Setu Process)
#  - Deactivate Cloud Setup/Services for Maxlife Insurance - Setu & Underwriting Process
#
# 🧠 Intent Cluster 3060 (10 tickets):
#  - Recording issue
#  - recording issue
#  - Recording issue
#  - Recording issue
#  - Recording issue
#
# 🧠 Intent Cluster 3953 (13 tickets):
#  - Incoming call issue
#  - Incoming Call Issue
#  - Incoming call issue
#  - Incoming calls issue
#  - Incoming call issue
#
# 🧠 Intent Cluster 978 (4 tickets):
#  - Rename Disposition- Indigo
#  - Indigo Disposition
#  - Sub Disposition Changes - Vernost Indigo
#  - Disposition Changes_Vernost Indigo
#
# 🧠 Intent Cluster 1221 (3 tickets):
#  - DID add on
#  - DID Add
#  - DID add
#
# 🧠 Intent Cluster 1578 (6 tickets):
#  - License renewal for the month of July 2025
#  - License renewal for the month of July 2025
#  - License renewal for the month of July 2025
#  - License renewal for the month of July 2025
#  - License renewal for the month of July 2025
#
# 🧠 Intent Cluster 2315 (9 tickets):
#  - New Cloud JRF : OID-27062025-0296 - Across Assist - Additional License -10 DC/DR
#  - New Cloud JRF : OID-08102024-2755 || Across Assist - Additional 10 User License ||
#  - New Cloud JRF OID-16082024-2668 - Across Assist - Additional 10 User License
#  - New Cloud JRF : OID-26122023-2264 | Swiggy_Inbound -Additional 10 Supervisor License - FOC
#  - New Cloud JRF : OID-19122023-2249 - Quampetence - Additional 10 User License
#
# 🧠 Intent Cluster 437 (5 tickets):
#  - Robo and Preview Dump
#  - Robo and Preview Dump
#  - Robo and Preview Dump
#  - Robo and Preview Dump
#  - Required-Robo and Preview Dump
#
# 🧠 Intent Cluster 3336 (7 tickets):
#  - voice file is not playing
#  - Voice file not showing
#  - Voice file is not playing
#  - Voice file is not vieweing
#  - Unable To Play Voice File
#
# 🧠 Intent Cluster 826 (4 tickets):
#  - Cloud Deactivate Support Services || UVA Technologies & Professional Services LLP
#  - Cloud Deactivate Support Services || UVA Technologies & Professional Services LLP
#  - Cloud Deactivate Support Services - OBDU EV (P) Ltd
#  - Cloud Deactivate Support Services || Plugger Technologies Pvt Ltd ||
#
# 🧠 Intent Cluster 3870 (8 tickets):
#  - Facing voice issue
#  - Facing voice issue
#  - Re: Facing voice issue
#  - Facing voice issue
#  - Facing voice issue
#
# 🧠 Intent Cluster 2508 (3 tickets):
#  - Request For campaign creation
#  - Campaign Creation Request
#  - Campaign Creation request
#
# 🧠 Intent Cluster 1672 (3 tickets):
#  - SK Prepone Campaign Data Dialing Issue |incNut Process Hyd |
#  - Calls Not dialing SK Prepone Campaign | IncNut Process | Hyd |
#  - Data Not Getting Dialed SK Prepone Campaign | IncNut Process HYD|
#
# 🧠 Intent Cluster 1461 (9 tickets):
#  - ssl certificate
#  - RE: self signed SSL certificate
#  - self signed SSL certificate
#  - SSL Certificate
#  - RE: SSL Certificate
#
# 🧠 Intent Cluster 2824 (3 tickets):
#  - number not connect
#  - Number not connected
#  - Number not connect
#
# 🧠 Intent Cluster 1276 (3 tickets):
#  - Urgent: Issue While Transferring Call Recording Files to Hard Disk
#  - Issue with Moving Recorded Files to Hard Drive
#  - Urgent: Issue with Moving Recorded Files to Hard Drive
#
# 🧠 Intent Cluster 1511 (16 tickets):
#  - New Skill Michelin and DID 1204501472 and 8065211472 Creation request
#  - New Skill Ensuredit and DID 0120-450-1468 Creation request
#  - New DID and Skill TICM Creation Request - 0120-450-1467
#  - New Skill and DID creation request 0120-450-1466
#  - New Skill D2C and DID 0120-450-1459 creation request
#
# 🧠 Intent Cluster 3536 (3 tickets):
#  - Need to change IVR
#  - Need to change IVR
#  - Need to change IVR
#
# 🧠 Intent Cluster 3591 (14 tickets):
#  - Call recording needed
#  - Need Call - Recording
#  - Need call recording
#  - Call Recording Required
#  - Required Call Recordings
#
# 🧠 Intent Cluster 2193 (3 tickets):
#  - Unable to check details
#  - Unable to Fetch Details
#  - Unable to Fetch details
#
# 🧠 Intent Cluster 1158 (9 tickets):
#  - Lead Details
#  - Lead Details
#  - Lead Details
#  - Lead Details
#  - Lead Details
#
# 🧠 Intent Cluster 1535 (3 tickets):
#  - 10 license transfer
#  - 10 license transfer
#  - 10 license tranfer
#
# 🧠 Intent Cluster 2668 (8 tickets):
#  - Outbound call not landing in TATA Play process
#  - Calls are not landing in TATA Play Process
#  - call not landing TATA Play Mumbai Location
#  - call not landing TATA Play Mumbai Location
#  - call not landing TATA Play
#
# 🧠 Intent Cluster 1104 (59 tickets):
#  - Invitation: C_zentrix recording @ Fri Jun 27, 2025 4pm - 4:30pm (IST) (helpdesk@c-zentrix.com)
#  - Invitation: Libas x Score AI: Undertanding Integration with C-Zentrix @ Thu Jun 19, 2025 3pm - 3:45pm (IST) (helpdesk@c-zentrix.com)
#  - Invitation: Scaler x C-Zentrix @ Fri Jun 6, 2025 2:30pm - 3:30pm (IST) (helpdesk@c-zentrix.com)
#  - Invitation: SIP Update @ Wed May 14, 2025 3pm - 4pm (IST) (helpdesk@c-zentrix.com)
#  - Invitation: C-Zentrix @ Sat May 10, 2025 11am - 11:30am (IST) (helpdesk@c-zentrix.com)
#
# 🧠 Intent Cluster 2214 (11 tickets):
#  - New Cloud JRF : OID-27062025-0295 - New Admin License || Bewakoof Brand Pvt Ltd
#  - New Cloud JRF : OID-11032025-3096 - 2 Admin License Required || Alankit Assignment Limited
#  - New Cloud FOC JRF OID-04032025-3062 : 1 Omni Admin Lic || Refyne Tech Pvt Ltd
#  - New Cloud FOC JRF : OID-25022025-3045 - Admin License Required || Refit Global Pvt Ltd ||
#  - New Cloud FOC JRF : OID-16072024-2612 : VLCC - One Admin Lic
#
# 🧠 Intent Cluster 4243 (3 tickets):
#  - Unable to login Czen admin portal
#  - Not able to login to C-zen Admin Portal
#  - Unable to login c-zentix admin portal
#
# 🧠 Intent Cluster 3080 (3 tickets):
#  - Password issue
#  - Password issue.
#  - password issue
#
# 🧠 Intent Cluster 2502 (8 tickets):
#  - Campaign Change
#  - Change of Campaign
#  - Change in Campaign
#  - Campaign Changes
#  - Campaign change
#
# 🧠 Intent Cluster 2757 (3 tickets):
#  - Agent Login - 46232 & 4973
#  - Agent Login - 46230 & 46226
#  - Agent Login - 4974 & 4975
#
# 🧠 Intent Cluster 654 (4 tickets):
#  - Response Not Received
#  - Response Not receives
#  - Response Not receive
#  - Response Not Received
#
# 🧠 Intent Cluster 2742 (7 tickets):
#  - Change in DID number - Achats Bangalore Campaign
#  - Change in DID number - Achats Bangalore Campaign
#  - Change in DID number - Achats Bangalore Campaign
#  - Change in DID number - Achats Bangalore Campaign
#  - Change in DID number - Achats Bangalore Campaign
#
# 🧠 Intent Cluster 2751 (4 tickets):
#  - Change in DID number - Achats Robo
#  - Change in DID number - Achats Robo
#  - Achats Robo - Change in DID number
#  - Change in DID Number - Achats Robo
#
# 🧠 Intent Cluster 1072 (3 tickets):
#  - Removal of disoposition
#  - Remove disposition
#  - Remove Disposition
#
# 🧠 Intent Cluster 3197 (3 tickets):
#  - CRM
#  - CRM
#  - CRM
#
# 🧠 Intent Cluster 749 (4 tickets):
#  - Change DID|TATA play
#  - DID change - TATA Play
#  - DID Change TATA pLAY
#  - RE: Change Dailing Intenisty - TATA Play
#
# 🧠 Intent Cluster 2550 (2 tickets):
#  - Regarding IVR Update for Non-Working Hours
#  - IVR Update for changed working hours
#
# 🧠 Intent Cluster 478 (6 tickets):
#  - Reduce Space ASAP
#  - Urgent: Reduce space
#  - IMP: Reduce Space
#  - Reduce Space
#  - Low space
#
# 🧠 Intent Cluster 1861 (7 tickets):
#  - Recording Releated.
#  - Recording
#  - Recording
#  - Recording
#  - Voice recording
#
# 🧠 Intent Cluster 2143 (4 tickets):
#  - New Cloud FOC JRF : OID-25062025-0290 - (Internal Ticketing CRM for Dealers) || Anand Rathi Share and Stock Brokers Limited
#  - New Cloud FOC JRF : OID-25062025-0290 - (Internal Ticketing CRM for Dealers) || Anand Rathi Share and Stock Brokers Limited
#  - Subject : New Cloud JRF : OID-29042025-0129 (Internal Ticketing CRM for Dealers) || Anand Rathi Share and Stock Brokers Limited
#  - New Cloud JRF : OID-29042025-0129 (Internal Ticketing CRM for Dealers) || Anand Rathi Share and Stock Brokers Limited
#
# 🧠 Intent Cluster 3891 (8 tickets):
#  - Voice breaking issue
#  - Voice breaking issue
#  - Voice breaking issue
#  - Voice breaking issue
#  - Voice breaking issue
#
# 🧠 Intent Cluster 2989 (14 tickets):
#  - Not Able to get IVR report
#  - Unable to fetch IVR Transfer/ ACD Report
#  - Unable to fetch IVR report againt Number
#  - RE: IVR Feedback Report not found
#  - IVR report not fetch
#
# 🧠 Intent Cluster 2274 (3 tickets):
#  - New Cloud JRF : OID-12062025-0256 - (RASA Derm) || Continuum Aesthetics Pvt Ltd
#  - New Cloud JRF : OID-12062025-0256 - (RASA Derm) || Continuum Aesthetics Pvt Ltd
#  - New Cloud JRF : OID-30092024-2740 | Clinic Dermatech - JRF
#
# 🧠 Intent Cluster 844 (4 tickets):
#  - Report Connection on INBOUD Calls
#  - Report Connection on INBOUD Calls
#  - Report Connection on INBOUD Calls
#  - Report Connection on INBOUD Calls
#
# 🧠 Intent Cluster 244 (3 tickets):
#  - Need to revert the changes made yesterday || IVR â Non-Registered Users: Press 1 / Press 2 Flow - 23 Jun\\ 25
#  - Re: Re: IVR â Non-Registered Users: Press 1 / Press 2 Flow - 23 Jun\\ 25
#  - IVR â Non-Registered Users: Press 1 / Press 2 Flow - 23 Jun\\ 25
#
# 🧠 Intent Cluster 4099 (11 tickets):
#  - Call Not connecting
#  - Call not Connecting
#  - Call not connecting
#  - Call not connecting
#  - Call not connecting
#
# 🧠 Intent Cluster 3747 (3 tickets):
#  - Agents are not able to login
#  - Agents are not able to login
#  - Agents are not able to login
#
# 🧠 Intent Cluster 458 (7 tickets):
#  - NO OF AGENTS :30  CALLING PROCESS :outbound  CALLING TYPE :international  DEPLOYMENT :On-Premise
#  - NO OF AGENTS :300  CALLING PROCESS :inbound  CALLING TYPE :domestic  DEPLOYMENT :On-Premise
#  - NO OF AGENTS :300  CALLING PROCESS :  CALLING TYPE :  DEPLOYMENT :
#  - NO OF AGENTS :300  CALLING PROCESS :blended  CALLING TYPE :both  DEPLOYMENT :On-Premise
#  - NO OF AGENTS :300  CALLING PROCESS :outbound  CALLING TYPE :both  DEPLOYMENT :On-Premise
#
# 🧠 Intent Cluster 1701 (3 tickets):
#  - New Cloud JRF : OID-24062025-0278 - International Setup Process || Winzo Games Pvt Ltd
#  - New Cloud JRF : OID-24062025-0278 - International Setup Process || Winzo Games Pvt Ltd
#  - New Cloud JRF : OID-24062025-0278 - International Setup Process || Winzo Games Pvt Ltd
#
# 🧠 Intent Cluster 3952 (3 tickets):
#  - Incoming/ outgoing call issue
#  - Incoming and Outgoing Call Issues
#  - Incoming and Outgoing Call Issues
#
# 🧠 Intent Cluster 1556 (7 tickets):
#  - New requirement
#  - New Requirement
#  - implement new requirement
#  - New DID requirement
#  - New Campaign Requirement
#
# 🧠 Intent Cluster 4031 (8 tickets):
#  - Facing dialer issue
#  - Facing dialer issue
#  - Facing dialer issue
#  - Facing dialer issue
#  - Facing dialer issue
#
# 🧠 Intent Cluster 3170 (5 tickets):
#  - Urgent: Customer Data Not Received in CRM
#  - RE: Customer details not fetching in CRM
#  - Customer details not fetching in CRM
#  - Unable to fetch customer\\ s details in the CRM
#  - CRM Issue Customer details are not showing.
#
# 🧠 Intent Cluster 2572 (3 tickets):
#  - New Cloud JRF : OID-23062025-0276 - Request to Create New Agent IDs on Cloud (2 user) || SMC Global Securities Pvt Ltd
#  - New Cloud JRF : OID-05052025-0138 - Request to Create Agent IDs on Cloud || SMC Global Securities Ltd
#  - New Cloud JRF : OID-23042025-0091 - Request to Create Agent IDs on Cloud || SMC Global Securities Ltd
#
# 🧠 Intent Cluster 3390 (8 tickets):
#  - Voice Logger issue
#  - Voice Logger Issue
#  - Voice Logger Issue
#  - Voice Logger Issue
#  - Voice Logger Issue
#
# 🧠 Intent Cluster 3136 (5 tickets):
#  - Reset the Password
#  - Reset the Password
#  - Reset the Password
#  - Reset the Password
#  - Reset the Password
#
# 🧠 Intent Cluster 2902 (11 tickets):
#  - Re: Issue || Client details Not display on the Agent UI
#  - Unable to show Agent status
#  - Agent Status is not appearing
#  - User detailare not showing on agent panel
#  - Data not showing on agentui
#
# 🧠 Intent Cluster 3915 (8 tickets):
#  - Voice Issue
#  - Voice Issue
#  - Voice Issue
#  - Voice Issue
#  - Voice Issue
#
# 🧠 Intent Cluster 2745 (3 tickets):
#  - Number change
#  - change of number
#  - Number Change
#
# 🧠 Intent Cluster 1247 (3 tickets):
#  - DNC List issue
#  - Unable to add number in DNC list
#  - DNC list not working
#
# 🧠 Intent Cluster 382 (3 tickets):
#  - increase bandwidth
#  - increase bandwidth tata sip
#  - need to bandwidth increase
#
# 🧠 Intent Cluster 2598 (4 tickets):
#  - Calls data missing in C-Zentrix Admin Panel
#  - Calls Data Not Found in C-Zentrix Admin Page
#  - Calls Data Not Found in C-Zentrix Admin Page
#  - FW: Calls Data Not Found in C-Zentrix Admin
#
# 🧠 Intent Cluster 1542 (3 tickets):
#  - Re : Install the SSL certificate
#  - Re: Re: Re : Install the SSL certificate
#  - Re : Install the SSL certificate
#
# 🧠 Intent Cluster 3721 (3 tickets):
#  - Agents Unable to Login
#  - Agents Are Unable to Login
#  - Agents Unable To Login
#
# 🧠 Intent Cluster 407 (944 tickets):
#  - Welcome Towards Vision Technologies Private Limited
#  - Welcome Towards Vision Technologies Private Limited
#  - Welcome Towards Vision Technologies Private Limited
#  - Welcome Towards Vision Technologies Private Limited
#  - Welcome Towards Vision Technologies Private Limited
#
# 🧠 Intent Cluster 2662 (4 tickets):
#  - IVR to be Updated _ 21st June\\ 25 (Saturday)
#  - IVR to be Updated _ 15th Feb\\ 25 (Saturday)
#  - IVR to be Updated _ 15th June\\ 24 (Saturday)
#  - IVR to be Updated _ 15th July\\ 23 (Saturday)
#
# 🧠 Intent Cluster 3480 (5 tickets):
#  - Fwd: Calls not landing
#  - FW: Calls not landing\\\"
#  - FW: Calls not landing \\\"
#  - FW: Call is not landing
#  - FW: Call are not landing\\\"
#
# 🧠 Intent Cluster 2326 (36 tickets):
#  - Mumbai Circle CRM ROBO calling Status Red.
#  - Mumbai Circle CRM ROBO calling Status Red.
#  - Mumbai Circle CRM ROBO calling Status Red.
#  - Mumbai Circle CRM ROBO calling Status Red.
#  - Mumbai Circle CRM ROBO calling Status Red.
#
# 🧠 Intent Cluster 3629 (8 tickets):
#  - Re : IVR call summary report issue
#  - getting issue in IVR reports
#  - IVR Reports Issue
#  - Invensis-Inprem || IVR Reports Issue
#  - IVR Report Issue
#
# 🧠 Intent Cluster 1154 (7 tickets):
#  - Leads Details
#  - Leads Details
#  - Leads Details
#  - Leads Details
#  - Leads Details
#
# 🧠 Intent Cluster 1980 (4 tickets):
#  - Voice logger access
#  - Access of Voice Logger
#  - Access for Voice Logger
#  - voice logger
#
# 🧠 Intent Cluster 89 (4 tickets):
#  - Process discussion
#  - Need to discuss
#  - Discussion
#  - Discussion
#
# 🧠 Intent Cluster 3790 (6 tickets):
#  - Abandoned Calls
#  - Abandoned calls
#  - Abandoned calls
#  - Abandoned Calls.
#  - Abandoned calls
#
# 🧠 Intent Cluster 3484 (6 tickets):
#  - Calls Not Syncing
#  - Call Not getting Synced
#  - Calls not getting sync.
#  - Calls are not syncing
#  - Calls not syncing
#
# 🧠 Intent Cluster 3784 (6 tickets):
#  - Zentrix issue
#  - Zentrix issue
#  - Issue with Zentrix
#  - Zentrix issue
#  - Zentrix related issue
#
# 🧠 Intent Cluster 3633 (3 tickets):
#  - not able to login agent in uat
#  - Agent not able to login in uat server
#  - Not able to login Agent in UAT
#
# 🧠 Intent Cluster 69 (13 tickets):
#  - Required RCA and CAPA for critical TT
#  - RCA and CAPA for critical TT
#  - RCA and CAPA for critical TT
#  - RCA and CAPA for Critical TT
#  - Required RCA and CAPA for Critical TT
#
# 🧠 Intent Cluster 4236 (5 tickets):
#  - Call not landing czentrix
#  - Call not landing czentrix
#  - C-zentrix Call not landing
#  - Czentrix Call not landing
#  - Czentrix Call not landing.
#
# 🧠 Intent Cluster 2811 (2 tickets):
#  - Discrepancy in Agent Break Report
#  - Discrepancy in \\\"Agent Summary\\\" Report
#
# 🧠 Intent Cluster 322 (9 tickets):
#  - DC call percentage exceeds the limit
#  - DC Calls Percentage Increasing
#  - DC Calls Percentage High
#  - DC Call percentage increase
#  - DC Percentage increase
#
# 🧠 Intent Cluster 2267 (5 tickets):
#  - Not able to upload list
#  - Unable to upload a list
#  - Unable to upload a list
#  - Unable to Upload List
#  - Unable to upload the List
#
# 🧠 Intent Cluster 83 (4 tickets):
#  - Request for OTP
#  - OTP
#  - OTP
#  - OTP Required
#
# 🧠 Intent Cluster 2897 (5 tickets):
#  - Call Dialing issue |IncNut Process | Hyderabad |
#  - Call Dialing Issue |incNut HYD |
#  - Call Dialing Issue | IncNut Process | Hyd
#  - SK FUP & SK Intelligent call Dialing Issue | IncNut Process | Hyderabad
#  - call disconnection issue (incNut process Hyderabad)
#
# 🧠 Intent Cluster 2211 (9 tickets):
#  - Requirement of DID\\ s
#  - DID Numbers Required
#  - DID Number
#  - DID Number Required
#  - DID required
#
# 🧠 Intent Cluster 3795 (33 tickets):
#  - New Czen ID Creation Required
#  - New Czen ID Creation Required
#  - New Czen ID Creation Required
#  - New Czen ID Creation Required
#  - New Czen ID Creation Required
#
# 🧠 Intent Cluster 1168 (3 tickets):
#  - Voice Recording to be uploaded - Reminder_alert
#  - Voice Recording to be uploaded - Reminder_alert
#  - Voice Recording to be uploaded - Reminder_alert
#
# 🧠 Intent Cluster 3510 (4 tickets):
#  - IVR Script Update
#  - IVR Script Update
#  - IVR Script Update
#  - IVR Script Update
#
# 🧠 Intent Cluster 2568 (6 tickets):
#  - CZ Outage
#  - CZ Down
#  - CZ Down
#  - CZ  Down
#  - CZ Down
#
# 🧠 Intent Cluster 1141 (4 tickets):
#  - C-zen Issue (19 June)
#  - C-Zen Issue 18 June
#  - C-zen Issue 12 June
#  - C-Zen Issue 06 June
#
# 🧠 Intent Cluster 1388 (5 tickets):
#  - Re: Disaster: rcms2: Free disk space is less than 15% on volume /
#  - Re: Disaster: rcms2: Free disk space is less than 15% on volume /
#  - Re: Disaster: rcms2: Free disk space is less than 15% on volume /
#  - Re: Disaster: rcms1: Free disk space is less than 15% on volume /
#  - Re: Disaster: rcms2: Free disk space is less than 15% on volume /
#
# 🧠 Intent Cluster 3581 (6 tickets):
#  - Unable to login through CZ-Bar
#  - Cz bar not login
#  - User is not able to login in CZ-Bar
#  - Unable to Log-in on CZ Bar
#  - Unable to login on czbar
#
# 🧠 Intent Cluster 4286 (5 tickets):
#  - C-Zentrix Calling issue.
#  - C-Zentrix Calling Issue.
#  - C-Zentrix Calling Issue.
#  - C-Zentrix Calling issue.
#  - C-zentrix call issue.
#
# 🧠 Intent Cluster 3072 (13 tickets):
#  - Intermittent Issue with Missing Beep Sound on Incoming Calls
#  - Beep Sound Not Captured for Incoming Calls
#  - Getting beep sound on calls
#  - Issue with the beep sound when a call lands
#  - Re: Not getting beep sound when call lands
#
# 🧠 Intent Cluster 2292 (3 tickets):
#  - New Agent creation
#  - RE: Agents creation
#  - Agents creation
#
# 🧠 Intent Cluster 3362 (5 tickets):
#  - unable to dispose call
#  - Unable to dispose the call
#  - Not able to dispose the call
#  - Unable to dispose the call
#  - Unable to dispose the call
#
# 🧠 Intent Cluster 2478 (17 tickets):
#  - pl Change Campaign Name
#  - Changes required in Campaign name
#  - Change The Campaign Name
#  - Change The Campaign Name
#  - Change my Campaign Name
#
# 🧠 Intent Cluster 3985 (3 tickets):
#  - Issue with outbound calls
#  - Issue with Outbound Calls
#  - Issue with outbound calls
#
# 🧠 Intent Cluster 3255 (6 tickets):
#  - Call transfer issue in cloud
#  - Cloud Call issue
#  - BDC Cloud calling issue
#  - Cloud || Calling issue
#  - PH Cloud || Calling issue
#
# 🧠 Intent Cluster 1975 (7 tickets):
#  - Created Outbound campaign
#  - Add Disposition and create outbound Campaign
#  - For Outbound Campaign regarding
#  - Re: Creating Outbound Campaign
#  - Regarding Outbound Campaign Management
#
# 🧠 Intent Cluster 1707 (2 tickets):
#  - Reverse Calling Issue
#  - Reverse calling issues
#
# 🧠 Intent Cluster 1123 (4 tickets):
#  - CLI Change
#  - CLI Change
#  - CLI Change
#  - CLI change
#
# 🧠 Intent Cluster 4153 (6 tickets):
#  - Facing Czen Issue
#  - Facing Czen Issue
#  - Facing Czen Issue
#  - Facing czen issue
#  - Facing Czen Issue
#
# 🧠 Intent Cluster 4172 (70 tickets):
#  - C-ZENTRIX ISSUE
#  - C-ZENTRIX ISSUE
#  - C-ZENTRIX ISSUE
#  - C-ZENTRIX ISSUE
#  - C-ZENTRIX ISSUE
#
# 🧠 Intent Cluster 3791 (12 tickets):
#  - C-Zentrix call connecting & Voice breaking Issue || West Region
#  - C-Zentrix call connecting & Voice breaking Issue // North Region
#  - C-Zentrix call connecting & voice breaking issue // North ,West & East Region
#  - Call voice breaking Issue through C-zentrix // North Region
#  - Call voice breaking Issue through C-zentrix // North Region
#
# 🧠 Intent Cluster 41 (58 tickets):
#  - Rate 2025-6-01 to 2025-6-17, Towards Vision Technologies Private Limited Bandwidth Alert,Base- 30.00 Mbps Usage- 30.66 Mbps
#  - Rate 2025-6-01 to 2025-6-15, Towards Vision Technologies Private Limited Bandwidth Alert,Base- 30.00 Mbps Usage- 30.20 Mbps
#  - Rate 2025-6-01 to 2025-6-14, Towards Vision Technologies Private Limited Bandwidth Alert,Base- 30.00 Mbps Usage- 30.20 Mbps
#  - Rate 2025-5-01 to 2025-5-28, Towards Vision Technologies Private Limited Bandwidth Alert,Base- 30.00 Mbps Usage- 32.60 Mbps
#  - Rate 2025-5-01 to 2025-5-12, Towards Vision Technologies Private Limited Bandwidth Alert,Base- 30.00 Mbps Usage- 30.29 Mbps
#
# 🧠 Intent Cluster 1424 (2 tickets):
#  - unableto make manuvaal call in ttbs
#  - manuval call issue in TTBS process.
#
# 🧠 Intent Cluster 3438 (4 tickets):
#  - RE: New DID
#  - New DID
#  - New DID Creation
#  - RE: New DID Creation
#
# 🧠 Intent Cluster 2682 (4 tickets):
#  - Re: IVR_file
#  - Regarding IVR files
#  - Inprem- Invensis - IVR File
#  - IVR File
#
# 🧠 Intent Cluster 477 (3 tickets):
#  - Calls to be Re-routed from 8826007956 to 8010488888 from 21st June to 30th June 2025
#  - Calls to be Re-routed from 1800-100-1212 to 8010488888 from 18th to 21st April 2025
#  - Calls to be Re-routed from 1800-100-1212 to 8010488888 from 26th February to 02nd March 2025
#
# 🧠 Intent Cluster 2832 (8 tickets):
#  - FW: Issue of CRM
#  - FW: CRM error
#  - FW: CRM error
#  - Fw: CRM LOGIN ERROR
#  - FW: CRM Tool issue
#
# 🧠 Intent Cluster 1401 (7 tickets):
#  - Outbound DID showing as spam
#  - Outbound DID spam report
#  - DID Showing Spam
#  - DID showing Spam
#  - DID resembling in Spam list
#
# 🧠 Intent Cluster 3337 (5 tickets):
#  - Re: Voice file not found
#  - Voice file Doesn\\ t Exist
#  - Voice file does not exist
#  - Voice file does not exist
#  - "Voice file does not exist" error
#
# 🧠 Intent Cluster 3978 (7 tickets):
#  - Inbound Call Issue
#  - inbound call issue
#  - Inbound Call issue
#  - Inbound Call issue
#  - Inbound call issue
#
# 🧠 Intent Cluster 4416 (13 tickets):
#  - C-zentrix login Issue
#  - C-zentrix login issue
#  - C-zentrix login issue
#  - C-zentrix login issue
#  - C-zentrix login issue
#
# 🧠 Intent Cluster 4350 (6 tickets):
#  - c-zentrix not working
#  - c-zentrix not working
#  - c-zentrix not working
#  - c-zentrix not working
#  - c-zentrix not working
#
# 🧠 Intent Cluster 2229 (3 tickets):
#  - New Cloud JRF : OID-16062025-0264 - 15 DID Required || TIDE Platform Pvt Ltd
#  - New Cloud JRF : OID-09062025-0251 - 30 New DIDs requirement || TIDE Platform Pvt Ltd
#  - New Cloud JRF : OID-23052024-2504 - New requirement Enquiry || TIDE Platform Pvt Ltd ||
#
# 🧠 Intent Cluster 1839 (5 tickets):
#  - Preview is not showing
#  - Issue with Preview Option
#  - Regarding preview mode
#  - Preview mode not working
#  - preview option  is not showing
#
# 🧠 Intent Cluster 1428 (5 tickets):
#  - unable to take backup
#  - Unable to take Backup
#  - Unable to take Backup
#  - Unable to take backup
#  - Unable to take the backup
#
# 🧠 Intent Cluster 1739 (6 tickets):
#  - Cluster || Bulk Id deativation
#  - India Cluster || Bulk Id deactivation request
#  - India Cluster || Bulk Id deativation
#  - India Cluster || Bulk Id deativation
#  - India Cluster || Bulk Dectiavtion
#
# 🧠 Intent Cluster 3418 (3 tickets):
#  - Delay in calls
#  - Delay in calls
#  - Delay in calls
#
# 🧠 Intent Cluster 508 (5 tickets):
#  - Urgent Request: Cleaning Root Partition Logs
#  - Urgent Request: Cleaning Root Partition Logs
#  - Urgent Request: Cleaning Root Partition Logs
#  - Urgent Request: Cleaning Root Partition Logs
#  - Urgent Request: Cleaning Root Partition Logs
#
# 🧠 Intent Cluster 408 (67 tickets):
#  - Welcome Towards Vision Technologies Private Limited
#  - Welcome Towards Vision Technologies Private Limited
#  - Welcome Towards Vision Technologies Private Limited
#  - Welcome Towards Vision Technologies Private Limited
# ...
#  - Call Originate Failure
#  - Call Orginate Failure
#
# 🧠 Intent Cluster 687 (67 tickets):
#  - Server health check report (OYO ROOMS)
#  - Server health check report (OYO ROOMS)
#  - Server health check report (OYO ROOMS)
#  - Server health check report (OYO ROOMS)
#  -
# Server health check report (OYO ROOMS)
#
#
# 🧠 Intent Cluster 699 (2 tickets):
#  - Server Health check report
#  - Server Health check report
#
# 🧠 Intent Cluster 774 (3 tickets):
#  - Start slave at qbix on 13.07.2022
#  - Start slave at qbix on 13.07.2022
#  - Start slave at qbix on 13.06.2022
#
# 🧠 Intent Cluster 698 (6 tickets):
#  -  Server health check report  (shopclues & aegis)
#  - Server health check report  (shopclues & aegis)
#  - Server health check
# report  (shopclues & aegis
# )
#  - Server health check report  (shopclues & aegis)
#  - Server health check report
# (shopclues & aegis)
#
# 🧠 Intent Cluster 105 (3 tickets):
#  - VADS Server monitoring
#  - VADS Server monitoring
#  - VADS Server monitoring
#
# 🧠 Intent Cluster 360 (4 tickets):
#  - UI open Issue
#  - UI open Issue
#  - UI open issue
#  - UI open Issue
#
# 🧠 Intent Cluster 2834 (3 tickets):
#  - Xlite Not Found Error
#  - Xlite Not Found Error
#  - Xlite error not found
#
# 🧠 Intent Cluster 107 (55 tickets):
#  - VADS server monitoring
#  - VADS server monitoring
#  -
# VADS server monitoring
#
#  -
# VADS server monitoring
#
#  - VADS server monitoring
#
# 🧠 Intent Cluster 3089 (3 tickets):
#  - Reset Password Issue_
#  - Password reset issue
#  - Reset Password issue
#
# 🧠 Intent Cluster 551 (5 tickets):
#  - A-Stats screen blank
#  - A- Stats is Blank
#  - Screen Blank
#  - A-Stats screen blank
#  - A- Stats is Blank
#
# 🧠 Intent Cluster 917 (4 tickets):
#  - New JRF: Cloud > DB Monitoring & Repair : 2022-23/00071/00074
#  - New JRF: Cloud > DB Monitoring & Repair : 2022-23/00071/00074
#  - New JRF: Cloud > DB Monitoring & Repair : 2022-23/00071/00074
#  - New JRF: Cloud > DB Monitoring & Repair : 2022-23/00071/00074
#
# 🧠 Intent Cluster 119 (5 tickets):
#  - Hold Aux Issue_All Queue
#  - C_Zentrix Issue_All Queue
#  - OOO Re: C_Zentrix Issue_All Queue
#  - C_Zentrix Issue_All Queue
#  - C_Zentrix Issue_All Queue
#
# 🧠 Intent Cluster 2240 (4 tickets):
#  - TVS LMPO page is not open
#  - RE: TVS LMP page is not open
#  - TVS LMP page is not open
#  - TVS LMP page is not open
#
# 🧠 Intent Cluster 737 (5 tickets):
#  - Re: API Issue on LMS & C-Zentrix Integration
#  - Subject : Re: API Issue on LMS & C-Zentrix Integration
#
#  - RE: API Issue on LMS & C-Zentrix Integration
#  - RE: API Issue on LMS & C-Zentrix Integration
#  - API Issue on LMS & C-Zentrix Integration
#
# 🧠 Intent Cluster 711 (48 tickets):
#  - Server health check report (shopclues And
# Aegis)
#  - Server health check report (shopclues And
# Aegis)
#  - Server health check report (shopclues
# And Aegis)
#  - Server health check report (shopclues And
# Aegis)
#  - Server health check report
# (shopclues And Aegis)
#
# 🧠 Intent Cluster 128 (3 tickets):
#  - ADVISORY: “CREATING A INCIDENT / Service Request THROUGH E-mail”
#  - ADVISORY: “CREATING A INCIDENT / Service Request THROUGH E-mail”
#  - ADVISORY: “CREATING A INCIDENT / Service Request THROUGH E-mail”
#
# 🧠 Intent Cluster 93 (3 tickets):
#  - Important Advisory: Server Host Protection –Critical
#  - Important Advisory: Server Host Protection –Critical
#  - Important Advisory: Server Host Protection –Critical
#
# 🧠 Intent Cluster 57 (3 tickets):
#  - ADVISORY - Identity & Access Management for Controlled Access to Your
#  Environment
#  - ADVISORY - Identity & Access Management for Controlled Access to Your
#  Environment
#  - ADVISORY - Identity & Access Management for Controlled Access to Your
#  Environment
#
# 🧠 Intent Cluster 125 (3 tickets):
#  - Escalation Matrix for IT Operation Team of NTT Global Data Centers
#  and Cloud Infrastructure India Pvt Ltd.
#  - Escalation Matrix for IT Operation Team of NTT Global Data Centers
#  and Cloud Infrastructure India Pvt Ltd.
#  - Escalation Matrix for IT Operation Team of NTT Global Data Centers
#  and Cloud Infrastructure India Pvt Ltd.
#
# 🧠 Intent Cluster 71 (3 tickets):
#  - Advisory Protecting Your Infrastructure Environment
#  - Advisory Protecting Your Infrastructure Environment
#  - Advisory Protecting Your Infrastructure Environment
#
# 🧠 Intent Cluster 5 (3 tickets):
#  - DATA CENTER VISITS
#  - DATA CENTER VISITS
#  - DATA CENTER VISITS
#
# 🧠 Intent Cluster 597 (3 tickets):
#  - UPDATE CONTACT DETAILS FOR BETTER CUSTOMER EXPERIENCE
#  - UPDATE CONTACT DETAILS FOR BETTER CUSTOMER EXPERIENCE
#  - UPDATE CONTACT DETAILS FOR BETTER CUSTOMER EXPERIENCE
#
# 🧠 Intent Cluster 888 (18 tickets):
#  - New Internal JRF (Cloud) > CZ Timezone changes/ Mixing changes >: 2022-23/00070/00073
#  - New Internal JRF (Cloud) > CZ Timezone changes/ Mixing changes >: 2022-23/00070/00073
#  - New Internal JRF (Cloud) > CZ Timezone changes/ Mixing changes >: 2022-23/00070/00073
#  - New Internal JRF (Cloud) > CZ Timezone changes/ Mixing changes >: 2022-23/00070/00073
#  - New Internal JRF (Cloud) > CZ Timezone changes/ Mixing changes >: 2022-23/00070/00073
#
# 🧠 Intent Cluster 1391 (2 tickets):
#  - Need to restart the samba services
#  - Need to restart the samba services
#
# 🧠 Intent Cluster 726 (43 tickets):
#  - Cloud SIP and PRI monitoring
#  -
# Cloud SIP and PRI monitoring
#
#  - Cloud SIP and PRI monitoring
#  - Cloud SIP and PRI monitoring
#  - Cloud SIP and PRI monitoring
#
# 🧠 Intent Cluster 710 (10 tickets):
#  - Server health check report (shopclues
# And Aegis)
#  -
#
#
#
# Server health check report (shopclues And Aegis)
#
#
#
#
#  - Server health check report (shopclues And Aegis)
#  - Server health check report (shopclues And Aegis)
#  -
#
#
#
# Server health check report (shopclues And Aegis)
#
#
#
#
#
#
# 🧠 Intent Cluster 700 (5 tickets):
#  - Server health check report
#  - Server health check report
#  -
# Server health check report
#
#  -
#
#
#
# Server health check report
#
#
#
#
#
#  - Server health check report
#
# 🧠 Intent Cluster 281 (3 tickets):
#  - Cnd dialer 5th 6th 7th
#  - CND Dialer / 5th 6th 7th
#  - Re: CND Dialer / 5th 6th 7th
#
# 🧠 Intent Cluster 3665 (3 tickets):
#  - C-Zen Issue || Unable to Logged in & Voice call is not coming
#  - C-Zen Issue || Unable to Logged in & Voice Call not coming.
#  - C-Zen Issue || Unable to Logged in & Voice Call not coming.
#
# 🧠 Intent Cluster 4294 (4 tickets):
#  - C-ZENTRIX NOT WORKING.
#  - C-ZENTRIX NOT WORKING.
#  - C-ZENTRIX NOT WORKING.
#  - C-ZENTRIX NOT WORKING.
#
# 🧠 Intent Cluster 4093 (3 tickets):
#  - C-Zentrix login Issue | 04-Jul-2022
#  - CZentrix login Issue | 01-Jul-2022
#  - Re: CZentrix login Issue | 01-Jul-2022
#
# 🧠 Intent Cluster 701 (105 tickets):
#  - Server health check report
#  - Server health check report
#  -
# Server health check report
#
#  - Server health check report
#  - Server health check report
#
# 🧠 Intent Cluster 2184 (4 tickets):
#  - RE: c zentrix hanging
#  - RE: c zentrix hanging
#  - RE: c zentrix hanging
#  - RE: c zentrix hanging
#
# 🧠 Intent Cluster 725 (5 tickets):
#  -
# Cloud SIP and PRI monitoring
#
#  - Cloud SIP and PRI monitoring
#  - Cloud SIP and PRI monitoring
#  - Cloud SIP and PRI monitoring
#
#  - Cloud SIP and PRI monitoring
#
#
# 🧠 Intent Cluster 198 (3 tickets):
#  - Security Advisory - RISE OF LNK (SHORTCUT FILES) MALWARE
#  - Security Advisory - RISE OF LNK (SHORTCUT FILES) MALWARE
#  - Security Advisory -  FORMBOOK MALWARE ON THE RISE
#
# 🧠 Intent Cluster 1759 (3 tickets):
#  - Re: Re: Problems Faced in CZAdmin Portal
#  - Re: Re: Problems Faced in CZAdmin Portal
#  - Re: Problems Faced in CZAdmin Portal
#
# 🧠 Intent Cluster 1347 (4 tickets):
#  - C-Zentrix Agent ID unable to Exit after last call from 04:38 PM
#  - C-Zentrix Agent ID unable to Exit after last call from 10:40AM
#  - C-Zentrix Agent ID unable to Exit after last call from 10:50AM
#  (Deepika)
#  - C-Zentrix Agent ID unable to Exit after last call from 10:50AM
#
# 🧠 Intent Cluster 1611 (6 tickets):
#  - License renewal Of  July 2022
#  - License renewal of July 2022.
#  - License renewal Of July 2022.
#  - License renewal For July 2022
#  - License renewal for July 2022
#
# 🧠 Intent Cluster 541 (3 tickets):
#  - FW: Dialer Logic need to be set and Wraptime
#  - Dialer Logic need to be set and Wraptime
#  - Dialer Logic need to be set and Wraptime
#
# 🧠 Intent Cluster 3656 (2 tickets):
#  - call landing issue
#  - call landing issue
#
# 🧠 Intent Cluster 2012 (3 tickets):
#  - South region| TN circle |IN-1060645 | ROBO call not received |29 june
#  22
#  - South region| TN circle |IN-1274401|ROBO call not received |09 june
#  22
#  - South region| KK circle |IN-1071049|ROBO call not received |08 june
#  22
#
# 🧠 Intent Cluster 414 (3 tickets):
#  - RE: Agent Logout Auto Closure | Noida Cloud Setup
#  - RE: Agent Logout Auto Closure | Noida Cloud Setup
#  - RE: Agent Logout Auto Closure | Noida Cloud Setup
#
# 🧠 Intent Cluster 1616 (9 tickets):
#  - License renewal for June 2022
#  - License renewal for June 2022
#  - License renewal for June 2022
#  - License renewal for June 2022
#  - License renewal for June 2022
#
# 🧠 Intent Cluster 106 (2 tickets):
#  - VADS server monitoring
#  -
#
#
#
# VADS server monitoring
#
#
#
#
#
#
# 🧠 Intent Cluster 498 (3 tickets):
#  - Security Advisory - Remote Code Execution Vulnerability in OpenSSL
#  (CVE-2022-2068)
#  - Security Advisory - CONFLUENCE SERVER AND DATA CENTER -
#  CVE-2022-26134 - CRITICAL UNAUTHENTICATED REMOTE CODE EXECUTION VULNERABILITY
#  - Security Advisory - CISCO SMALL BUSINESS RV SERIES ROUTERS REMOTE
#  CODE EXECUTION VULNERABILITY (CVE-2022-20753)
#
# 🧠 Intent Cluster 526 (3 tickets):
#  - Shreeji Project IVR Upload urgent 242
#  - FW: Shreeji Project IVR Upload urgent
#  - FW: Shreeji Project IVR Upload | Urgent
#
# 🧠 Intent Cluster 1767 (5 tickets):
#  - C-Zentrix -Admin portal Agent Details not visible | South Region
#  - C-Zentrix -Admin portal Agent Details not visible | South Region
#  - C-Zentrix -Admin portal Agent Details not visible | South Region
#  - C-Zentrix -Admin portal Agent Details not visible | South Region
#  - C-Zentrix -Admin portal Agent Details not visible |South Region
#
# 🧠 Intent Cluster 405 (6 tickets):
#  - Project Status Report - Towards Vision Technologies Private Limited
#  - Project Status Report - Towards Vision Technologies Private Limited
#  - Project Status Report - Towards Vision Technologies Private Limited
#  - Project Status Report - Towards Vision Technologies Private Limited
#  - Project Status Report - Towards Vision Technologies Private Limited
#
# 🧠 Intent Cluster 1446 (2 tickets):
#  - Calls are not lending (Inbound Camp- Faircent)
#  - Calls not lending
#
# 🧠 Intent Cluster 4165 (3 tickets):
#  - C-zentrix calls are not connecting Properly and Disconnected
#  automatically |  20-JUNE'22
#  - C-zentrix calls are not connecting Properly and Disconnected
#  automatically |  10-JUNE'22
#  - C-zentrix calls are not connecting Properly and Disconnected
#  automatically, 06/Jun/22
#
# 🧠 Intent Cluster 2200 (3 tickets):
#  - New Cloud POC JRF : OID-20062022-1085 | Comviva | CCaaS setup with IP address
#  -  New Cloud POC JRF : OID-20062022-1085 | Comviva | CCaaS setup with IP address
#  - New Cloud POC JRF : OID-20062022-1085 | Comviva | CCaaS setup with IP
#  address
#
# 🧠 Intent Cluster 722 (5 tickets):
#  - Clorrud SIP and PRI monitoring
#  - Clorrud SIP and PRI monitoring
#  - Clorrud SIP and PRI monitoring
#  - Clorrud SIP and PRI monitoring
#  - Clorrud SIP and PRI monitoring
#
# 🧠 Intent Cluster 721 (2 tickets):
#  - Clorrud SIP and PRI monitoring
#  - Clorrud SIP and PRI monitoring
#
# 🧠 Intent Cluster 3088 (4 tickets):
#  - Dialer ID Creation of New Agents
#  - Re: Dialer ID Creation of New Agents
#  - Re: Dialer ID Creation of New Agents
#  - Dialer ID Creation of New Agents
#
# 🧠 Intent Cluster 216 (3 tickets):
#  - RE: C-zentrix DID access to Vatsal Mohite / Prem Yadav / Sumukh
#  Patankar
#  - C-zentrix DID access to Vatsal Mohite / Prem Yadav
#  - C-zentrix DID access to Sandeep Wankhade
#
# 🧠 Intent Cluster 555 (3 tickets):
#  - RE: FW: Request For Additional Headers For Cash_karo_CI_Campaign
#  - RE: FW: Request For Additional Headers For Cash_karo_CI_Campaign
#  - Request For Additional Headers For Cash_karo_CI_Campaign
#
# 🧠 Intent Cluster 2576 (3 tickets):
#  - C-zentrix Server 10.105.127.10 showing Disk Error
#  - C-zentrix Server 10.105.127.10 showing Disk Error
#  - C-zentrix Server 10.105.127.10 showing Disk Error
#
# 🧠 Intent Cluster 1976 (3 tickets):
#  - Call are disconnecting(450197)
#  - Re: Calls are disconnecting (44040)
#  - Calls are disconnecting (44040)
#
# 🧠 Intent Cluster 1560 (3 tickets):
#  - RE: Need to movement the licenses
#  - RE: Need to movement the licenses
#  - Need to movement the licenses
#
# 🧠 Intent Cluster 1624 (2 tickets):
#  - log clearance
#  - log clearance
#
# 🧠 Intent Cluster 734 (3 tickets):
#  - Conference not happening in 220 server
#  - Re: Conference not working
#  - Conference not working
#
# 🧠 Intent Cluster 2227 (4 tickets):
#  - Subject : New Cloud JRF : OID-28012022-729 | Mama Earth | New Customer
#  - Subject : New Cloud JRF : OID-28012022-729 | Mama Earth | New Customer
#  - Subject : New Cloud JRF : OID-28012022-729 | Mama Earth | New Customer
#  - New Cloud JRF : OID-28012022-729 | Mama Earth | New Customer
#
# 🧠 Intent Cluster 1632 (3 tickets):
#  - LOGS CLEAR
#  - LOGS CLEAR
#  - LOGS CLEAR
#
# 🧠 Intent Cluster 2159 (4 tickets):
#  - New Cloud JRF : OID (080622/36) | Max LIfe Insurance | Max Cloud
#  Claims Team
#  - Re: Subject : New Cloud JRF : OMS ID (2022-23/00048) | Max Life
#  Insurance Co. Ltd | MLI || NEOM Project
#  - Subject : New Cloud JRF : OMS ID (2022-23/00048) | Max Life Insurance Co. Ltd | MLI || NEOM Project
#  - New Cloud JRF : OMS ID (2022-23/00048) | Max Life Insurance Co. Ltd |
#  MLI || NEOM Project
#
# 🧠 Intent Cluster 1865 (6 tickets):
#  - CND IVR
#  - CND IVR Activation
#  - CND IVR
#  - CND IVR
#  - RE: CND IVR
#
# 🧠 Intent Cluster 1766 (4 tickets):
#  - C-Zentrix -Admin portal not visible agent details |South Region
#  07/06/22
#  - C-Zentrix -Admin portal not visible agent details |South Region
#  - C-Zentrix -Admin portal not visible agent details |South Region
#  - C-Zentrix -Admin portal not visible agent details |South Region
#
# 🧠 Intent Cluster 61 (3 tickets):
#  - Re: FW: Fairassets Tata SIP details (Series 8068196900 to
#  8068196999||NEW TT--611955557
#  - Re: FW: Fairassets Tata SIP details (Series 8068196900 to
#  8068196999-NEW TT--611919355
#  - Re: FW: Fairassets Tata SIP details (Series 8068196900 to 8068196999
#  Not Active)
#
# 🧠 Intent Cluster 223 (3 tickets):
#  - Test License for 3 days
#  - Test license for 3 days
#  - Test License for 3 days
#
# 🧠 Intent Cluster 2187 (4 tickets):
#  - Subject : New JRF : OMS ID (2022-23/00060) | CEBC (Wipro) | CRM Customization
#  - New JRF : OMS ID (2022-23/00060) | CEBC (Wipro) | CRM Customization
#  - Subject : New JRF : OMS ID (2022-23/00031) || On-premise || ?CBEC (Through Wipro LTD) || Wipro || CRM Customization
#  - New JRF : OMS ID (2022-23/00031) || On-premise || ?CBEC (Through Wipro LTD) || Wipro || CRM Customization
#
# 🧠 Intent Cluster 3051 (5 tickets):
#  - CZentrix | Issue in Calls Connection | 28-May-2022
#  - CZentrix | Issue in Calls Connection | 28-May-2022
#  - CZentrix | Issue in Calls Connection | 26-May-2022
#  - CZentrix | Issue in Calls Connection | 24-May-2022
#  - CZentrix | Issue in Calls Connection | 14-May-2022
#
# 🧠 Intent Cluster 3568 (2 tickets):
#  - Czen- Issue- Call is Landing Via C-Zen but muted in call process-
#  - C-zen Issue:- Call is not Landing Via C-Zen & if Landing then muted
#  in call process(Fluctuating).
#
# 🧠 Intent Cluster 1020 (3 tickets):
#  - Request to close Admin and Agent Account
#  - Re: Request to close one admin account
#  - Request to close one admin account
#
# 🧠 Intent Cluster 260 (4 tickets):
#  - Re: NTT DC outage
#  - RE: NTT DC outage
#  - Re: NTT DC outage
#  - Re: NTT DC outage
#
# 🧠 Intent Cluster 4044 (3 tickets):
#  - Call is not Landing Via C-Zen----
#  - Call is not Landing Via C-Zen
#  - Call is not Landing Via C-Zen
#
# 🧠 Intent Cluster 121 (12 tickets):
#  - As we have put on the servers on 25/05/22
#  - As we have put on the servers on 24/05/22
#  - As we have put on the servers on 23/05/22
#  - As we have put on the servers on 21/05/22
#  - As we have put on the servers on 20/05/22
#
# 🧠 Intent Cluster 865 (3 tickets):
#  - restart all services on 192.168.10.248 & 246
#  - restart all services on 192.168.10.248 & 246
#  - Also restart all services 192.168.10.246 / 248
#
# 🧠 Intent Cluster 4019 (3 tickets):
#  - Call Issue_
#  - Calls Issue_
#  - Call Issue_
